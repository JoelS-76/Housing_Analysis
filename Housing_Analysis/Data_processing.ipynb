# %%
# Import dependencies
import os
import pandas as pd

# %%
# importing housing data
house_df = pd.read_excel('Resources/clean_House_prices.xlsx')
house_df.head()
# Out:
#         CountyName           1997           1998           1999  \
# 0    Denver County  144211.083333  157625.333333  175471.916667
# 1   El Paso County  142508.916667  147672.916667  155935.500000
# 2  Arapahoe County  133396.916667  143271.666667  158078.333333
# 3   Larimer County  163194.666667  168924.833333  181416.916667
# 4    Pueblo County   90495.750000   95448.666667  102374.000000
#
#             2000           2001           2002           2003           2004  \
# 0  202976.333333  232443.583333  246901.750000  249635.461538  254793.583333
# 1  163330.083333  177515.833333  186842.166667  192284.461538  198514.916667
# 2  180677.916667  206261.916667  215658.250000  218679.153846  220339.000000
# 3  196578.083333  218750.500000  233787.166667  239067.615385  245698.583333
# 4  108664.583333  111731.000000  114387.333333  118079.000000  123091.500000
#
#             2005  ...           2007           2008           2009  \
# ...

# %%
# importing income data
income_df = pd.read_excel('Resources/CO_income.xlsx')
income_df
# Out:
#      areatyname           areaname  periodyear  periodtype pertypdesc  \
# 0        County    La Plata County        1997           1     Annual
# 1        County    Montrose County        1997           1     Annual
# 2        County     Fremont County        1997           1     Annual
# 3        County    Arapahoe County        1997           1     Annual
# 4        County    Huerfano County        1997           1     Annual
# ...         ...                ...         ...         ...        ...
# 1271     County        Lake County        2016           1     Annual
# 1272     County       Eagle County        2016           1     Annual
# 1273     County      Pueblo County        2016           1     Annual
# 1274     County    Gunnison County        2016           1     Annual
# 1275     County  Rio Grande County        2016           1     Annual
#
#                                              incdesc income  population
# ...

# %%
cleaned_house_df = house_df.groupby(['CountyName']).mean()
cleaned_house_df
# Out:
#                             1997           1998           1999           2000  \
# CountyName
# Adams County       128133.405556  138042.472222  153253.533333  175973.177778
# Alamosa County      67630.875000   66069.177778   69118.444444   73833.472222
# Arapahoe County    269897.303571  281234.130952  314151.220238  360547.946429
# Archuleta County             NaN            NaN            NaN            NaN
# Baca County                  NaN            NaN            NaN            NaN
# ...                          ...            ...            ...            ...
# Summit County                NaN            NaN  223403.226852  250463.111111
# Teller County      103601.833333  109636.100000  117109.483333  127863.416667
# Washington County            NaN            NaN            NaN            NaN
# Weld County        164598.623457  173410.191358  190099.425926  205095.793210
# Yuma County                  NaN            NaN            NaN            NaN
#
# ...

# %%
counties_list = list(cleaned_house_df.index.values)
counties_list
# Out:
# ['Adams County',
#  'Alamosa County',
#  'Arapahoe County',
#  'Archuleta County',
#  'Baca County',
#  'Bent County',
#  'Boulder County',
#  'Broomfield County',
#  'Chaffee County',
#  'Cheyenne County',
#  'Clear Creek County',
#  'Conejos County',
#  'Costilla County',
#  'Crowley County',
#  'Custer County',
#  'Delta County',
#  'Denver County',
#  'Dolores County',
#  'Douglas County',
#  'Eagle County',
#  'El Paso County',
#  'Elbert County',
#  'Fremont County',
#  'Garfield County',
#  'Gilpin County',
#  'Grand County',
#  'Gunnison County',
#  'Hinsdale County',
#  'Huerfano County',
#  'Jackson County',
#  'Jefferson County',
#  'Kiowa County',
#  'Kit Carson County',
#  'La Plata County',
#  'Lake County',
#  'Larimer County',
#  'Las Animas County',
#  'Lincoln County',
#  'Logan County',
#  'Mesa County',
#  'Mineral County',
#  'Moffat County',
#  'Montezuma County',
#  'Montrose County',
#  'Morgan County',
#  'Otero County',
#  'Ouray County',
#  'Park County',
# ...

# %%
period_list = income_df.periodyear.unique()
period_list
# Out:
# array([1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016], dtype=int64)

# %%
# header = ["County", "Year", "House_price"]
# import csv
# with open("Resources/house_price.csv", "w", newline="") as house_data:
#     csvwriter = csv.writer(house_data )
#     csvwriter.writerow(header)
#     for county in counties_list:
#         for period in period_list:
#             house_price = cleaned_house_df.loc[county, period]
#             csvwriter.writerow([county, period, house_price])

# %%
# importing housing data
house_df = pd.read_excel('Resources/house_df.xlsx')
econ_df = pd.read_excel('Resources/CO_industries_GDP_changes.xlsx')

# %%
house_df
# Out:
#       County  Year  House_price
# 0     Adams   1997  128133.4056
# 1     Adams   1998  138042.4722
# 2     Adams   1999  153253.5333
# 3     Adams   2000  175973.1778
# 4     Adams   2001  201303.3556
# ...      ...   ...          ...
# 1275   Yuma   2012  102651.1429
# 1276   Yuma   2013  110623.4762
# 1277   Yuma   2014  120436.2976
# 1278   Yuma   2015  131109.8095
# 1279   Yuma   2016  147907.7024
#
# [1280 rows x 3 columns]

# %%
# box_office = box_office.apply(lambda x: ' '.join(x) if type(x) == list else x)
# df['Volume'] = df['Volume'].astype('str')

# df['Volume'] = df['Volume'].astype('str')
# df['Volume'] = df['Volume'].str.replace(',', '')

# %%
house_df.dtypes
# Out:
# County          object
# Year             int64
# House_price    float64
# dtype: object

# %%
econ_df
# convert county data type into string
# convert GDP_Change into numeric
# Out:
#       year county                                        Description  \
# 0     2010  Adams         Agriculture, forestry, fishing and hunting
# 1     2010  Adams      Mining, quarrying, and oil and gas extraction
# 2     2010  Adams                                      Manufacturing
# 3     2010  Adams  Educational services, health care, and social ...
# 4     2010  Adams  Arts, entertainment, recreation, accommodation...
# ...    ...    ...                                                ...
# 3295  2019   Yuma      Mining, quarrying, and oil and gas extraction
# 3296  2019   Yuma                                      Manufacturing
# 3297  2019   Yuma  Educational services, health care, and social ...
# 3298  2019   Yuma  Arts, entertainment, recreation, accommodation...
# 3299  2019   Yuma                    Accommodation and food services
#
#       LineCode  GeoFips GDP_Change
# 0            3     8001       31.9
# 1            6     8001        1.4
# ...

# %%
econ_house_df = pd.merge(econ_df, house_df, left_on=['year', 'county'], right_on=['Year','County'], how="left")
econ_house_df[econ_house_df.year == 2010]
# Out:
#      year county                                        Description  LineCode  \
# 0    2010  Adams         Agriculture, forestry, fishing and hunting         3
# 1    2010  Adams      Mining, quarrying, and oil and gas extraction         6
# 2    2010  Adams                                      Manufacturing        12
# 3    2010  Adams  Educational services, health care, and social ...        68
# 4    2010  Adams  Arts, entertainment, recreation, accommodation...        75
# ..    ...    ...                                                ...       ...
# 325  2010   Yuma      Mining, quarrying, and oil and gas extraction         6
# 326  2010   Yuma                                      Manufacturing        12
# 327  2010   Yuma  Educational services, health care, and social ...        68
# 328  2010   Yuma  Arts, entertainment, recreation, accommodation...        75
# 329  2010   Yuma                    Accommodation and food services        79
#
# ...

# %%
# df['winner'] = np.select(conditions, choices, default='Tie')
import numpy as np
conditions = [econ_df.year.unique() == house_df.Year.unique]
choices = ["same"]

compare = np.select(conditions, choices, default='NO')
compare
# Out:
# array(['NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO'],
#       dtype='<U4')

# %%
# df.columns = df.columns.str.strip()
house_df.County = house_df.County.str.strip()
house_df.County.unique()
# Out:
# array(['Adams', 'Alamosa', 'Arapahoe', 'Archuleta', 'Baca', 'Bent',
#        'Boulder', 'Broomfield', 'Chaffee', 'Cheyenne', 'Conejos',
#        'Costilla', 'Crowley', 'Custer', 'Delta', 'Denver', 'Dolores',
#        'Douglas', 'Eagle', 'Elbert', 'Fremont', 'Garfield', 'Gilpin',
#        'Grand', 'Gunnison', 'Hinsdale', 'Huerfano', 'Jackson',
#        'Jefferson', 'Kiowa', 'Lake', 'Larimer', 'Lincoln', 'Logan',
#        'Mesa', 'Mineral', 'Moffat', 'Montezuma', 'Montrose', 'Morgan',
#        'Otero', 'Ouray', 'Park', 'Phillips', 'Pitkin', 'Prowers',
#        'Pueblo', 'Routt', 'Saguache', 'Sedgwick', 'Summit', 'Teller',
#        'Washington', 'Weld', 'Yuma', None], dtype=object)

# %%
econ_house_df = pd.merge(econ_df, house_df, left_on=['year', 'county'], right_on=['Year','County'], how="left")
econ_house_df.count()
# Out:
# year           3300
# county         3300
# Description    3300
# LineCode       3300
# GeoFips        3300
# GDP_Change     3300
# County         2310
# Year           2310
# House_price    2214
# dtype: int64

# %%
# pd.isna(df['column_name'])
empty_df = econ_house_df[econ_house_df.County.isna()]
empty_df
# Out:
#       year county                                        Description  \
# 2310  2017  Adams         Agriculture, forestry, fishing and hunting
# 2311  2017  Adams      Mining, quarrying, and oil and gas extraction
# 2312  2017  Adams                                      Manufacturing
# 2313  2017  Adams  Educational services, health care, and social ...
# 2314  2017  Adams  Arts, entertainment, recreation, accommodation...
# ...    ...    ...                                                ...
# 3295  2019   Yuma      Mining, quarrying, and oil and gas extraction
# 3296  2019   Yuma                                      Manufacturing
# 3297  2019   Yuma  Educational services, health care, and social ...
# 3298  2019   Yuma  Arts, entertainment, recreation, accommodation...
# 3299  2019   Yuma                    Accommodation and food services
#
#       LineCode  GeoFips GDP_Change County  Year  House_price
# 2310         3     8001      -11.8    NaN   NaN          NaN
# ...

# %%
empty_df.year.unique()
# Out:
# array([2017, 2018, 2019], dtype=int64)

# %%
econ_house_df = econ_house_df.dropna()
econ_house_df.drop(columns=['County', 'Year'])
# Out:
#       year county                                        Description  \
# 0     2010  Adams         Agriculture, forestry, fishing and hunting
# 1     2010  Adams      Mining, quarrying, and oil and gas extraction
# 2     2010  Adams                                      Manufacturing
# 3     2010  Adams  Educational services, health care, and social ...
# 4     2010  Adams  Arts, entertainment, recreation, accommodation...
# ...    ...    ...                                                ...
# 2305  2016   Yuma      Mining, quarrying, and oil and gas extraction
# 2306  2016   Yuma                                      Manufacturing
# 2307  2016   Yuma  Educational services, health care, and social ...
# 2308  2016   Yuma  Arts, entertainment, recreation, accommodation...
# 2309  2016   Yuma                    Accommodation and food services
#
#       LineCode  GeoFips GDP_Change County    Year  House_price
# 0            3     8001       31.9  Adams  2010.0  186966.9500
# ...

# %%
econ_house_df.to_csv("Resources/econ_house.csv")

# %%
interest_df = pd.read_excel("Resources/mortgage_rate_data.xls")
interest_df.head()
# Out:
#         Week  U.S. 30 yr FRM 30 yr fees & points  U.S. 15 yr FRM  \
# 0 1971-04-02            7.33                                 NaN
# 1 1971-04-09            7.31                                 NaN
# 2 1971-04-16            7.31                                 NaN
# 3 1971-04-23            7.31                                 NaN
# 4 1971-04-30            7.29                                 NaN
#
#    15 yr fees & points  U.S. 5/1 ARM  5/1 ARM fees & points  \
# 0                  NaN           NaN                    NaN
# 1                  NaN           NaN                    NaN
# 2                  NaN           NaN                    NaN
# 3                  NaN           NaN                    NaN
# 4                  NaN           NaN                    NaN
#
#    U.S. 5/1 ARM margin  30 yr FRM/ 5/1 ARM spread
# 0                  NaN                        NaN
# 1                  NaN                        NaN
# 2                  NaN                        NaN
# ...

# %%
# df['year'] = pd.DatetimeIndex(df['birth_date']).year
interest_df['Year'] = pd.to_datetime(interest_df.Week)
interest_df['Year'] = pd.DatetimeIndex(interest_df['Week']).year

# %%
interest_df = interest_df[(interest_df.Year >= 2010) & (interest_df.Year <= 2016)]

# %%
interest_df.groupby('Year').mean()
# Out:
#       U.S. 30 yr FRM  U.S. 15 yr FRM  15 yr fees & points  U.S. 5/1 ARM  \
# Year
# 2010        4.689808        4.095577             0.667308      3.824808
# 2011        4.447885        3.684231             0.709615      3.310962
# 2012        3.657500        2.934423             0.684615      2.784808
# 2013        3.975577        3.100769             0.700000      2.877885
# 2014        4.168868        3.286038             0.571698      3.019245
# 2015        3.850577        3.087500             0.576923      2.939038
# 2016        3.654038        2.930769             0.492308      2.876923
#
#       5/1 ARM fees & points  U.S. 5/1 ARM margin  30 yr FRM/ 5/1 ARM spread
# Year
# 2010               0.626923             2.744615                        NaN
# 2011               0.596154             2.740769                        NaN
# 2012               0.646154             2.741234                        NaN
# ...
