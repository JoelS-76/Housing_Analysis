# %%
# Import dependencies
import os
import pandas as pd
from sqlalchemy import create_engine
from config import db_password

# %%
# importing housing data
house_df = pd.read_excel('Working Data/clean_House_prices.xlsx')
house_df.head()
# Out:
#         CountyName           1997           1998           1999  \
# 0    Denver County  144211.083333  157625.333333  175471.916667
# 1   El Paso County  142508.916667  147672.916667  155935.500000
# 2  Arapahoe County  133396.916667  143271.666667  158078.333333
# 3   Larimer County  163194.666667  168924.833333  181416.916667
# 4    Pueblo County   90495.750000   95448.666667  102374.000000
#
#             2000           2001           2002           2003           2004  \
# 0  202976.333333  232443.583333  246901.750000  249635.461538  254793.583333
# 1  163330.083333  177515.833333  186842.166667  192284.461538  198514.916667
# 2  180677.916667  206261.916667  215658.250000  218679.153846  220339.000000
# 3  196578.083333  218750.500000  233787.166667  239067.615385  245698.583333
# 4  108664.583333  111731.000000  114387.333333  118079.000000  123091.500000
#
#             2005  ...           2007           2008           2009  \
# ...

# %%
# importing income data
income_df = pd.read_excel('Working Data/CO_income_clean.xlsx')
income_df
# Out:
#                  County  Year  Income  Population
# 0       La Plata County  1997   36822     41654.0
# 1       Montrose County  1997   32312     31460.0
# 2        Fremont County  1997   29939     43825.0
# 3       Arapahoe County  1997   50748    462681.0
# 4       Huerfano County  1997   21389      7553.0
# ...                 ...   ...     ...         ...
# 1271        Lake County  2016   49064         NaN
# 1272       Eagle County  2016   79556         NaN
# 1273      Pueblo County  2016   44644         NaN
# 1274    Gunnison County  2016   53753         NaN
# 1275  Rio Grande County  2016   41128         NaN
#
# [1276 rows x 4 columns]

# %%
# Read in csv file
pricing_out_df = pd.read_csv('Working Data/pricing_out.csv')
pricing_out_df.head()
# Out:
#    Unnamed: 0  year county                                        Description  \
# 0           0  2010  Adams         Agriculture, forestry, fishing and hunting
# 1           1  2010  Adams      Mining, quarrying, and oil and gas extraction
# 2           2  2010  Adams                                      Manufacturing
# 3           3  2010  Adams  Educational services, health care, and social ...
# 4           4  2010  Adams  Arts, entertainment, recreation, accommodation...
#
#   GDP_Change  House_price  Income  interest_rate  lending_limit  periods  \
# 0       31.9    186966.95   52785         0.0025           0.25      360
# 1        1.4    186966.95   52785         0.0025           0.25      360
# 2       -3.5    186966.95   52785         0.0025           0.25      360
# 3        6.5    186966.95   52785         0.0025           0.25      360
# 4        2.5    186966.95   52785         0.0025           0.25      360
#
#    suggest_payment  suggest_income priced_out
# ...

# %%
# Connection Strong to local server and database
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Housing-Database"

#postgresql//postgres:{db_password}@localhost:5432/Housing-Database
#"postgresql://[user]:[password]@[location]:[port]/[database]"

# %%
# Create database engine
engine = create_engine(db_string)

# %%
# Import housing data 
house_df.to_sql(name='Housing', con=engine)

# %%
# Import income data 
income_df.to_sql(name='Income', con=engine)

# %%
# Import pricing out data 
pricing_out_df.to_sql(name='Pricing Out', con=engine)
