# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Import dependencies
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from sklearn.model_selection import train_test_split
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Read in csv dataset
final_county_df = pd.read_csv('final_county.csv')
final_county_df.head()
# Out:
#   County  Year  Population  GDP_pct_Change   House_Price   Income Priced_Out
# 0  Adams  2010      441603            6.78  $186,966.95   52785.0          N
# 1  Adams  2011      451443           15.78  $176,663.41   52429.0          N
# 2  Adams  2012      459861           -0.17  $181,639.65   55695.0          N
# 3  Adams  2013      469377           10.03  $204,357.18   54876.0          N
# 4  Adams  2014      479488           17.60  $228,642.09   59316.0          N

# %%
# Drop the dollar sign from the House_Price column
final_county_df['House_Price'] = final_county_df['House_Price'].str.replace('$', '')

# %%
# Check data types
final_county_df.dtypes
# Out:
# County             object
# Year                int64
# Population          int64
# GDP_pct_Change    float64
# House_Price        object
# Income            float64
# Priced_Out         object
# dtype: object

# %%
# Strip trailing spaces from House_Price
final_county_df.House_Price = final_county_df['House_Price'].str.strip()

# %%
final_county_df.head()
# Out:
#   County  Year  Population  GDP_pct_Change House_Price   Income Priced_Out
# 0  Adams  2010      441603            6.78  186,966.95  52785.0          N
# 1  Adams  2011      451443           15.78  176,663.41  52429.0          N
# 2  Adams  2012      459861           -0.17  181,639.65  55695.0          N
# 3  Adams  2013      469377           10.03  204,357.18  54876.0          N
# 4  Adams  2014      479488           17.60  228,642.09  59316.0          N

# %%
# Drop commas from House_Price
final_county_df['House_Price'] = final_county_df['House_Price'].str.replace(',', '')

# %%
final_county_df.head()
# Out:
#   County  Year  Population  GDP_pct_Change House_Price   Income Priced_Out
# 0  Adams  2010      441603            6.78   186966.95  52785.0          N
# 1  Adams  2011      451443           15.78   176663.41  52429.0          N
# 2  Adams  2012      459861           -0.17   181639.65  55695.0          N
# 3  Adams  2013      469377           10.03   204357.18  54876.0          N
# 4  Adams  2014      479488           17.60   228642.09  59316.0          N

# %%
# Convert House_Price to float
h= final_county_df['House_Price']
final_county_df.House_Price = pd.to_numeric(h)

# %%
# Check data types
final_county_df.dtypes
# Out:
# County             object
# Year                int64
# Population          int64
# GDP_pct_Change    float64
# House_Price       float64
# Income            float64
# Priced_Out         object
# dtype: object

# %%
# Remove decimals
final_county_df.House_Price = final_county_df.House_Price.round()

# %%
# Drop null values
final_county_df.dropna(inplace=True)

# %%
# Check for nulls
final_county_df.isnull().sum().sum()
# Out:
# 0

# %%
#Define target variable
target= 'Priced_Out'

# %%
# Create our features
X = final_county_df.drop(columns='Priced_Out')
X = pd.get_dummies(X)


# Create our target
y = final_county_df.loc[:, target].copy()

# %%
X.describe()
# Out:
#               Year     Population  GDP_pct_Change    House_Price  \
# count   353.000000     353.000000      353.000000     353.000000
# mean   2013.130312   88396.844193       14.305807  208488.413598
# std       2.008509  164139.179610       73.083535  138400.098037
# min    2010.000000     703.000000      -38.550000   33937.000000
# 25%    2011.000000    5597.000000       -5.720000   99594.000000
# 50%    2013.000000   16715.000000        3.500000  185859.000000
# 75%    2015.000000   47315.000000       12.730000  279130.000000
# max    2016.000000  694777.000000      767.870000  778773.000000
#
#               Income  County_Adams  County_Alamosa  County_Arapahoe  \
# count     353.000000    353.000000      353.000000       353.000000
# mean    51834.107649      0.019830        0.019830         0.019830
# std     15301.482746      0.139614        0.139614         0.139614
# min     26075.000000      0.000000        0.000000         0.000000
# 25%     41348.000000      0.000000        0.000000         0.000000
# 50%     47631.000000      0.000000        0.000000         0.000000
# 75%     61286.000000      0.000000        0.000000         0.000000
# max    112399.000000      1.000000        1.000000         1.000000
#
#        County_Archuleta  County_Baca  ...  County_Prowers  County_Pueblo  \
# count        353.000000   353.000000  ...      353.000000     353.000000
# mean           0.019830     0.019830  ...        0.019830       0.019830
# std            0.139614     0.139614  ...        0.139614       0.139614
# min            0.000000     0.000000  ...        0.000000       0.000000
# 25%            0.000000     0.000000  ...        0.000000       0.000000
# 50%            0.000000     0.000000  ...        0.000000       0.000000
# 75%            0.000000     0.000000  ...        0.000000       0.000000
# max            1.000000     1.000000  ...        1.000000       1.000000
#
#        County_Routt  County_Saguache  County_Sedgwick  County_Summit  \
# count    353.000000       353.000000       353.000000     353.000000
# mean       0.019830         0.008499         0.019830       0.019830
# std        0.139614         0.091925         0.139614       0.139614
# min        0.000000         0.000000         0.000000       0.000000
# 25%        0.000000         0.000000         0.000000       0.000000
# 50%        0.000000         0.000000         0.000000       0.000000
# 75%        0.000000         0.000000         0.000000       0.000000
# max        1.000000         1.000000         1.000000       1.000000
#
#        County_Teller  County_Washington  County_Weld  County_Yuma
# count     353.000000         353.000000   353.000000   353.000000
# mean        0.019830           0.019830     0.019830     0.019830
# std         0.139614           0.139614     0.139614     0.139614
# min         0.000000           0.000000     0.000000     0.000000
# 25%         0.000000           0.000000     0.000000     0.000000
# 50%         0.000000           0.000000     0.000000     0.000000
# 75%         0.000000           0.000000     0.000000     0.000000
# max         1.000000           1.000000     1.000000     1.000000
#
# [8 rows x 60 columns]

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# N    231
# Y    122
# Name: Priced_Out, dtype: int64

# %%
#Split the data for training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.preprocessing import StandardScaler

# Creating a StandardScaler instance.
scaler = StandardScaler()
# Fitting the Standard Scaler with the training data.
X_scaler = scaler.fit(X_train)

# Scaling the data.
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

brf_model = BalancedRandomForestClassifier(n_estimators=100, random_state=1)
brf_model = brf_model.fit(X_train_scaled, y_train)


y_pred = brf_model.predict(X_test_scaled)

# %%
#from sklearn.metrics import accuracy_score on training set
y_pred_train = brf_model.predict(X_train_scaled)
balanced_accuracy_score(y_train, y_pred_train)
# Out:
# 1.0

# %%
# Calculated the balanced accuracy score on test set
from sklearn.metrics import balanced_accuracy_score

balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.9833333333333334

# %%
# Display the confusion matrix
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
# Calculating the confusion matrix.
cm = confusion_matrix(y_test, y_pred)

# Create a DataFrame from the confusion matrix.
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

cm_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0           58            2
# Actual 1            0           29

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           N       1.00      0.97      1.00      0.98      0.98      0.96        60
#           Y       0.94      1.00      0.97      0.97      0.98      0.97        29
#
# avg / total       0.98      0.98      0.99      0.98      0.98      0.97        89

# %%
importances = sorted(zip(brf_model.feature_importances_, X.columns), reverse=True)
importances
# Out:
# [(0.15163233197104098, 'Population'),
#  (0.14171603294268367, 'House_Price'),
#  (0.13667112115390134, 'Income'),
#  (0.08098653613465541, 'GDP_pct_Change'),
#  (0.04593730958746017, 'Year'),
#  (0.028471462595121535, 'County_Elbert'),
#  (0.02195182386094187, 'County_Fremont'),
#  (0.017813082601966037, 'County_Sedgwick'),
#  (0.01703641771327847, 'County_Dolores'),
#  (0.01648755656361279, 'County_Conejos'),
#  (0.016464506104806147, 'County_Arapahoe'),
#  (0.015463019679430591, 'County_Lake'),
#  (0.0152948477825611, 'County_Eagle'),
#  (0.014338951458774762, 'County_Archuleta'),
#  (0.01266755773846543, 'County_Chaffee'),
#  (0.012089123335639156, 'County_Montezuma'),
#  (0.011823197313635105, 'County_Prowers'),
#  (0.011551770407760944, 'County_Montrose'),
#  (0.0111181065770286, 'County_Huerfano'),
#  (0.010943012178521, 'County_Morgan'),
#  (0.009160465664194227, 'County_Delta'),
#  (0.009133327222793296, 'County_Yuma'),
#  (0.008986600985826447, 'County_Boulder'),
#  (0.008977867018174704, 'County_Logan'),
#  (0.008866742903196468, 'County_Broomfield'),
#  (0.008363975763783999, 'County_Grand'),
#  (0.007888304539427892, 'County_Alamosa'),
#  (0.007853769562408843, 'County_Kiowa'),
#  (0.007672287149512934, 'County_Cheyenne'),
#  (0.007181863041735785, 'County_Lincoln'),
#  (0.006972153068410952, 'County_Teller'),
#  (0.006681357752982078, 'County_Moffat'),
#  (0.006493531907511093, 'County_Mineral'),
#  (0.005903852719252927, 'County_Routt'),
#  (0.005858819771996838, 'County_Bent'),
#  (0.0056821997189048954, 'County_Phillips'),
#  (0.00536615223572357, 'County_Gunnison'),
#  (0.005332612163604948, 'County_Washington'),
#  (0.005236836319649032, 'County_Mesa'),
#  (0.005016636973386419, 'County_Ouray'),
#  (0.004876852216919214, 'County_Otero'),
#  (0.004836786312249791, 'County_Jefferson'),
#  (0.004644624371451531, 'County_Larimer'),
#  (0.0044898678436792, 'County_Costilla'),
#  (0.004368846322162425, 'County_Pitkin'),
#  (0.004332590320799627, 'County_Custer'),
#  (0.004248704325331913, 'County_Weld'),
#  (0.004222592671186602, 'County_Summit'),
#  (0.004199406869739888, 'County_Douglas'),
#  (0.003902986953968749, 'County_Gilpin'),
#  (0.0035365836452318994, 'County_Baca'),
#  (0.0033888256626306255, 'County_Pueblo'),
#  (0.0027675148443156994, 'County_Saguache'),
#  (0.0027327164018944566, 'County_Jackson'),
#  (0.0022425107697337686, 'County_Adams'),
#  (0.002111385771987887, 'County_Crowley'),
#  (0.0015532549917897111, 'County_Garfield'),
#  (0.0015364892128193574, 'County_Denver'),
#  (0.0014713612309141186, 'County_Hinsdale'),
#  (0.0014489750774312714, 'County_Park')]
